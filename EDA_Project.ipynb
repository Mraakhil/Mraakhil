# %% [markdown]
# <a href="https://colab.research.google.com/github/Mraakhil/Mraakhil/blob/main/EDA_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Exploratory Data Anaysis Case Study: Electric_Vehicle_Population Data**
# ![](https://storage.googleapis.com/kaggle-datasets-images/3879361/6736736/c3579b70fc7f7c98bd9380dd9882a939/dataset-card.jpg?t=2023-10-19-06-58-37)
#
# Exploratory Data Analysis (EDA) is the process of exploring, investigating and gathering insights from data using statistical measures and visualizations. The objective of EDA is to develop and understanding of data, by uncovering trends, relationships and patterns.
#
# EDA is both a science and an art. On the one hand it requires the knowledge of statistics, visualization techniques and data analysis tools like Numpy, Pandas, Seaborn etc. On the other hand, it requires asking interesting questions to guide the investigation and interpreting numbers & figures to generate useful insights.

# %%
# !pip install opendatasets

# %%
data_link = 'https://drive.google.com/file/d/1KcoS287ZGCerwE0aYQ_uXlvPMSRYjEm7/view?usp=sharing'

# %%
data_link
# Out:
# 'https://drive.google.com/file/d/1KcoS287ZGCerwE0aYQ_uXlvPMSRYjEm7/view?usp=sharing'

# %%
import opendatasets as od

# %%
od.download(data_link)
# Out:
# ...
# 36482731it [00:00, 759323666.34it/s]
# Downloaded to  ./Electric_Vehicle_Population_Data.csv

# %% [markdown]
# This is used to download the dataset from the url.This dataset from the kaggle so i need to give my user name and the kaggle key which i use to create my kaggle account

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# Here's a brief description of each library:
#
# * Pandas: A powerful Python library used for data manipulation and analysis. It provides data structures like DataFrames and Series to work with tabular data efficiently. Pandas makes it easy to load, filter, aggregate, and clean datasets.
#
# * NumPy: This library adds support for large, multi-dimensional arrays and matrices, along with a collection of mathematical functions to operate on them. It's widely used for numerical computing and is foundational for many data science tasks.
#
# * Matplotlib: A plotting library used for creating static, interactive, and animated visualizations in Python. It's versatile for generating charts like line plots, bar graphs, histograms, and scatter plots.
#
# * Seaborn: Built on top of Matplotlib, Seaborn provides a high-level interface for creating attractive statistical graphics. It simplifies the creation of complex plots such as heatmaps, violin plots, and pair plots with minimal code.
#
# * Plotly Express: A part of the Plotly library, Plotly Express is an easy-to-use wrapper for creating interactive, web-based visualizations. It allows for quick plotting of scatter, line, bar, and pie charts with rich interactivity like zooming and hovering.

# %%
pd.set_option('display.max_columns',None)

# %% [markdown]
# 'display.max_columns': This option sets the maximum number of columns to display when printing a DataFrame. By default, Pandas limits the number of visible columns to prevent overwhelming the screen with too much information.
#
# None: Setting this to None removes the limit, allowing all columns in the DataFrame to be shown, regardless of how many there are.

# %% [markdown]
# #Loading the dataset

# %%
data = pd.read_csv('/content/Electric_Vehicle_Population_Data.csv')

# %%
data
# Out:
#         VIN (1-10)        County               City State  Postal Code  \
# 0       KM8K33AGXL          King            Seattle    WA      98103.0
# 1       1C4RJYB61N          King            Bothell    WA      98011.0
# 2       1C4RJYD61P        Yakima             Yakima    WA      98908.0
# 3       5YJ3E1EA7J          King           Kirkland    WA      98034.0
# 4       WBY7Z8C5XJ      Thurston            Olympia    WA      98501.0
# ...            ...           ...                ...   ...          ...
# 150477  WBY43AW05P  Grays Harbor          Montesano    WA      98563.0
# 150478  5YJ3E1EB7P          King            Seattle    WA      98104.0
# 150479  5YJYGDEEXM          King            Seattle    WA      98109.0
# 150480  5UXTA6C08P     Snohomish  Mountlake Terrace    WA      98043.0
# 150481  7SAYGDEF8N        Skagit       Mount Vernon    WA      98273.0
#
#         Model Year     Make           Model  \
# 0             2020  HYUNDAI            KONA
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150482 entries, 0 to 150481
# Data columns (total 17 columns):
#  #   Column                                             Non-Null Count   Dtype
# ---  ------                                             --------------   -----
#  0   VIN (1-10)                                         150482 non-null  object
#  1   County                                             150479 non-null  object
#  2   City                                               150479 non-null  object
#  3   State                                              150482 non-null  object
#  4   Postal Code                                        150479 non-null  float64
#  5   Model Year                                         150482 non-null  int64
#  6   Make                                               150482 non-null  object
#  7   Model                                              150482 non-null  object
# ...

# %%
data.columns
# Out:
# Index(['VIN (1-10)', 'County', 'City', 'State', 'Postal Code', 'Model Year',
#        'Make', 'Model', 'Electric Vehicle Type',
#        'Clean Alternative Fuel Vehicle (CAFV) Eligibility', 'Electric Range',
#        'Base MSRP', 'Legislative District', 'DOL Vehicle ID',
#        'Vehicle Location', 'Electric Utility', '2020 Census Tract'],
#       dtype='object')

# %%
selected_cols = ['VIN (1-10)', 'County', 'City', 'State', 'Postal Code', 'Model Year',
       'Make', 'Model', 'Electric Vehicle Type',
       'Clean Alternative Fuel Vehicle (CAFV) Eligibility', 'Electric Range',
       'Base MSRP', 'Legislative District', 'DOL Vehicle ID',
       'Vehicle Location', 'Electric Utility', '2020 Census Tract']

# %%
selected_cols
# Out:
# ['VIN (1-10)',
#  'County',
#  'City',
#  'State',
#  'Postal Code',
#  'Model Year',
#  'Make',
#  'Model',
#  'Electric Vehicle Type',
#  'Clean Alternative Fuel Vehicle (CAFV) Eligibility',
#  'Electric Range',
#  'Base MSRP',
#  'Legislative District',
#  'DOL Vehicle ID',
#  'Vehicle Location',
#  'Electric Utility',
#  '2020 Census Tract']

# %%
len(selected_cols)
# Out:
# 17

# %%
data[selected_cols]
# Out:
#         VIN (1-10)        County               City State  Postal Code  \
# 0       KM8K33AGXL          King            Seattle    WA      98103.0
# 1       1C4RJYB61N          King            Bothell    WA      98011.0
# 2       1C4RJYD61P        Yakima             Yakima    WA      98908.0
# 3       5YJ3E1EA7J          King           Kirkland    WA      98034.0
# 4       WBY7Z8C5XJ      Thurston            Olympia    WA      98501.0
# ...            ...           ...                ...   ...          ...
# 150477  WBY43AW05P  Grays Harbor          Montesano    WA      98563.0
# 150478  5YJ3E1EB7P          King            Seattle    WA      98104.0
# 150479  5YJYGDEEXM          King            Seattle    WA      98109.0
# 150480  5UXTA6C08P     Snohomish  Mountlake Terrace    WA      98043.0
# 150481  7SAYGDEF8N        Skagit       Mount Vernon    WA      98273.0
#
#         Model Year     Make           Model  \
# 0             2020  HYUNDAI            KONA
# ...

# %%
survey = data[selected_cols].copy()

# %%
survey
# Out:
#         VIN (1-10)        County               City State  Postal Code  \
# 0       KM8K33AGXL          King            Seattle    WA      98103.0
# 1       1C4RJYB61N          King            Bothell    WA      98011.0
# 2       1C4RJYD61P        Yakima             Yakima    WA      98908.0
# 3       5YJ3E1EA7J          King           Kirkland    WA      98034.0
# 4       WBY7Z8C5XJ      Thurston            Olympia    WA      98501.0
# ...            ...           ...                ...   ...          ...
# 150477  WBY43AW05P  Grays Harbor          Montesano    WA      98563.0
# 150478  5YJ3E1EB7P          King            Seattle    WA      98104.0
# 150479  5YJYGDEEXM          King            Seattle    WA      98109.0
# 150480  5UXTA6C08P     Snohomish  Mountlake Terrace    WA      98043.0
# 150481  7SAYGDEF8N        Skagit       Mount Vernon    WA      98273.0
#
#         Model Year     Make           Model  \
# 0             2020  HYUNDAI            KONA
# ...

# %% [markdown]
# #Cleaning the Dataset

# %% [markdown]
# #Checking for missing value

# %%
print(data.isnull().sum())
# Out:
# VIN (1-10)                                             0
# County                                                 3
# City                                                   3
# State                                                  0
# Postal Code                                            3
# Model Year                                             0
# Make                                                   0
# Model                                                  0
# Electric Vehicle Type                                  0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility      0
# Electric Range                                         0
# Base MSRP                                              0
# Legislative District                                 341
# DOL Vehicle ID                                         0
# Vehicle Location                                       7
# Electric Utility                                       3
# ...

# %%
survey.isna().sum()
# Out:
# VIN (1-10)                                             0
# County                                                 3
# City                                                   3
# State                                                  0
# Postal Code                                            3
# Model Year                                             0
# Make                                                   0
# Model                                                  0
# Electric Vehicle Type                                  0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility      0
# Electric Range                                         0
# Base MSRP                                              0
# Legislative District                                 341
# DOL Vehicle ID                                         0
# Vehicle Location                                       7
# Electric Utility                                       3
# ...

# %% [markdown]
# #Remove Duplicates

# %%
data = data.drop_duplicates()

# %%
data
# Out:
#         VIN (1-10)        County               City State  Postal Code  \
# 0       KM8K33AGXL          King            Seattle    WA      98103.0
# 1       1C4RJYB61N          King            Bothell    WA      98011.0
# 2       1C4RJYD61P        Yakima             Yakima    WA      98908.0
# 3       5YJ3E1EA7J          King           Kirkland    WA      98034.0
# 4       WBY7Z8C5XJ      Thurston            Olympia    WA      98501.0
# ...            ...           ...                ...   ...          ...
# 150477  WBY43AW05P  Grays Harbor          Montesano    WA      98563.0
# 150478  5YJ3E1EB7P          King            Seattle    WA      98104.0
# 150479  5YJYGDEEXM          King            Seattle    WA      98109.0
# 150480  5UXTA6C08P     Snohomish  Mountlake Terrace    WA      98043.0
# 150481  7SAYGDEF8N        Skagit       Mount Vernon    WA      98273.0
#
#         Model Year     Make           Model  \
# 0             2020  HYUNDAI            KONA
# ...

# %%
survey.isna().sum()/len(survey)
# Out:
# VIN (1-10)                                           0.000000
# County                                               0.000020
# City                                                 0.000020
# State                                                0.000000
# Postal Code                                          0.000020
# Model Year                                           0.000000
# Make                                                 0.000000
# Model                                                0.000000
# Electric Vehicle Type                                0.000000
# Clean Alternative Fuel Vehicle (CAFV) Eligibility    0.000000
# Electric Range                                       0.000000
# Base MSRP                                            0.000000
# Legislative District                                 0.002266
# DOL Vehicle ID                                       0.000000
# Vehicle Location                                     0.000047
# ...

# %%
survey.isna().sum()/len(survey)*100
# Out:
# VIN (1-10)                                           0.000000
# County                                               0.001994
# City                                                 0.001994
# State                                                0.000000
# Postal Code                                          0.001994
# Model Year                                           0.000000
# Make                                                 0.000000
# Model                                                0.000000
# Electric Vehicle Type                                0.000000
# Clean Alternative Fuel Vehicle (CAFV) Eligibility    0.000000
# Electric Range                                       0.000000
# Base MSRP                                            0.000000
# Legislative District                                 0.226605
# DOL Vehicle ID                                       0.000000
# Vehicle Location                                     0.004652
# ...

# %% [markdown]
# #Exploratory Data Analysis
#
# > Add blockquote

# %%
survey.describe()
# Out:
#          Postal Code     Model Year  Electric Range      Base MSRP  \
# count  150479.000000  150482.000000   150482.000000  150482.000000
# mean    98168.344154    2020.005436       67.877839    1312.644735
# std      2473.612184       3.015209       96.230009    9231.310215
# min      1730.000000    1997.000000        0.000000       0.000000
# 25%     98052.000000    2018.000000        0.000000       0.000000
# 50%     98122.000000    2021.000000       18.000000       0.000000
# 75%     98370.000000    2023.000000       97.000000       0.000000
# max     99577.000000    2024.000000      337.000000  845000.000000
#
#        Legislative District  DOL Vehicle ID  2020 Census Tract
# count         150141.000000    1.504820e+05       1.504790e+05
# mean              29.343950    2.111122e+08       5.297195e+10
# std               14.824829    8.196388e+07       1.638841e+09
# min                1.000000    4.385000e+03       1.081042e+09
# ...

# %%
sns.set(style="whitegrid")

# %%
fig, axes = plt.subplots(3, 1, figsize=(10, 15))

# %%
sns.histplot(data['Electric Range'], bins=30, kde=True, ax=axes[0], color='blue')
axes[0].set_title('Distribution of Electric Range')
axes[0].set_xlabel('Electric Range (miles)')
# Out:
# Text(0.5, 819.7385620915034, 'Electric Range (miles)')

# %%
sns.histplot(data['Model Year'], bins=30, kde=True, ax=axes[1], color='green')
axes[1].set_title('Distribution of Model Year')
axes[1].set_xlabel('Model Year')
# Out:
# Text(0.5, 412.0915032679739, 'Model Year')

# %%
sns.histplot(data['Base MSRP'], bins=30, kde=True, ax=axes[2], color='red')
axes[2].set_title('Distribution of Base MSRP')
axes[2].set_xlabel('Base MSRP')
# Out:
# Text(0.5, 4.444444444444473, 'Base MSRP')

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data['Electric Range'], bins=30, kde=True, color='blue')
plt.title('Distribution of Electric Range', fontsize=16)
plt.xlabel('Electric Range (miles)', fontsize=14)
plt.ylabel('Frequency', fontsize=14)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data['Model Year'], bins=30, kde=True, color='green')
plt.title('Distribution of Model Year', fontsize=16)
plt.xlabel('Model Year', fontsize=14)
plt.ylabel('Frequency', fontsize=14)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data['Base MSRP'], bins=30, kde=True, color='red')
plt.title('Distribution of Base MSRP', fontsize=16)
plt.xlabel('Base MSRP', fontsize=14)
plt.ylabel('Frequency', fontsize=14)
plt.show()
