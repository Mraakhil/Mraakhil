# %% [markdown]
# <a href="https://colab.research.google.com/github/Mraakhil/Mraakhil/blob/main/Untitled34.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.162 Safari/537.36'}
webpage =  requests.get('https://www.oyorooms.com/hotels-in-hyderabad/',headers=headers).text

# %%
soup = BeautifulSoup(webpage,'lxml')

# %%
soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html dir="ltr" lang="en">\n <head>\n  <meta charset="utf-8"/>\n  <meta content="ie=edge; chrome=1" httpequiv="x-ua-compatible"/>\n  <meta content="lCkLu-7S0Eb5LOgDgmoWxSWzbopNfzKW01ZEe3ldsOc" name="google-site-verification"/>\n  <script type="text/javascript">\n   window.renderingSource=\'server\'\n        var host = window.location.hostname;\n        if (!String.prototype.endsWith) {\n\t        String.prototype.endsWith = function(search, this_len) {\n\t\t        if (this_len === undefined || this_len > this.length) {\n\t\t\t        this_len = this.length;\n\t\t        }\n\t      \t  return this.substring(this_len - search.length, this_len) === search;\n\t        };\n        }\n        // if (! (host.endsWith("oyorooms.com") || host.endsWith("oyorooms.ms") || host.endsWith("oyohotels.co.jp") || host.endsWith("hotelesoyo.com") || host.endsWith("oyohotels.com") || host.endsWith("belvilla.co.in") || host.endsWith("oyorooms.io")) && host.indexOf(\'localhost\') < 0){\n
# ...

# %%
for i in soup.find_all('span',class_="hotelRating__ratingSummary  hotelRating__rating--clickable"):
    print(i.text)

# %%
name=[]
price=[]
allinfo=[]
rating=[]
facilities=[]
for i in  soup.find_all('h3'):
  name.append(i.text)
for i in soup.find_all('span',class_='listingPrice__finalPrice listingPrice__finalPrice--black'):
    price.append(i.text)
for i in soup.find_all('div',class_='listingPrice__numbers')  :
     allinfo.append(i.text)
for i in soup.find_all('div',class_='hotelRating'):
    rating.append(i.text)
for i in soup.find_all('div',class_='amenityWrapper') :
    facilities.append(i.text)

# %%
allinfo
# Out:
# ['₹929₹381272% off',
#  '₹839₹314568% off',
#  '₹1000₹414472% off',
#  '₹1022₹405970% off',
#  '₹1014₹480075% off',
#  '₹1777₹638768% off',
#  '₹1781₹676069% off',
#  '₹1312₹539472% off',
#  '₹1411₹507168% off',
#  '₹1232₹465069% off',
#  '₹1218₹450868% off',
#  '₹1188₹487572% off',
#  '₹840₹385774% off',
#  '₹813₹418577% off',
#  '₹823₹371173% off',
#  '₹836₹368873% off',
#  '₹1058₹460473% off',
#  '₹612₹313275% off',
#  '₹973₹424773% off',
#  '₹979₹418873% off']

# %%
location
# Out:
# ['Kondapur, Hyderabad',
#  'Malkajgiri, Hyderabad',
#  'Malkajgiri Dist, Hyderabad',
#  'Near Radhe Nagar, Gachibowli, Hyderabad',
#  'Kondapur, Hyderabad',
#  'Madhapur, Hyderabad',
#  'Near Red Hills, Hyderabad',
#  'Madhapur, Hyderabad',
#  'Champapet, Hyderabad',
#  'Telecom Nagar, Hyderabad',
#  'Chintalkunta, Hyderabad',
#  'Ameerpet Jamuna Tirth, Hyderabad',
#  'Near JNTU BUS STOP, Pragathi Nagar, Hyderabad',
#  'Dilsukhnagar, Hyderabad',
#  'Gachibowli, Hyderabad',
#  'Near KPHB Metro Station, Dominos Pizza Building, Beside South India shopping mall, Hyderabad',
#  'Gachibowli, Hyderabad',
#  'Kothapet, Hyderabad',
#  'Pragathi Nagar, Hyderabad',
#  'Kukatpally, Hyderabad']

# %%
name
# Out:
# ['Super Townhouse Kondapur Near Botanical Garden',
#  'Super Collection O Malkajgiri formerly Serene Woods',
#  'Townhouse OAK Kompally',
#  'Super Townhouse Oak Rai Durg',
#  'Super Hotel O Green Tree Guest House',
#  'Super Townhouse Oak Madhapur-II formerly Nera Regency',
#  'Super Townhouse Lakdikapul',
#  'Townhouse VIP Hills Hitech City',
#  'Super Townhouse Oak LB Nagar Ramoji formerly N7 Elite',
#  'Super Townhouse Gachibowli Near Sky View',
#  'Super Collection O Vanasthalipuram formerly MG Elite',
#  'Super Townhouse Begumpet Near Metro Stn formerly Townvilla',
#  'Super Hotel O JNTU college Near LULU mall, KPHB Colony.',
#  'Super Collection O RCC MARVEL',
#  'Super Collection O Gachibowli formerly Vinayaka',
#  'Super Hotel O Sahasra Residency 43619 Near Nexus Hyderabad',
#  'Super Collection O Gachibowli Phase 2',
#  'Hotel O FLAGSHIP HOTEL RAMOJI BESIDE OMNI HOSPITAL KOTHAPET',
#  'Super Townhouse La Vista Inn Grand Hotel ',
# ...

# %%
len(name)
# Out:
# 20

# %%
d={'name':name,'price':price,'allinfo':allinfo,'rating':rating,'facilities':facilities}

# %%
df = pd.DataFrame(d)

# %%
df
# Out:
#                                                  name  price  \
# 0      Super Townhouse Kondapur Near Botanical Garden   ₹929
# 1   Super Collection O Malkajgiri formerly Serene ...   ₹839
# 2                              Townhouse OAK Kompally  ₹1000
# 3                        Super Townhouse Oak Rai Durg  ₹1022
# 4                Super Hotel O Green Tree Guest House  ₹1014
# 5   Super Townhouse Oak Madhapur-II formerly Nera ...  ₹1777
# 6                          Super Townhouse Lakdikapul  ₹1781
# 7                     Townhouse VIP Hills Hitech City  ₹1312
# 8   Super Townhouse Oak LB Nagar Ramoji formerly N...  ₹1411
# 9            Super Townhouse Gachibowli Near Sky View  ₹1232
# 10  Super Collection O Vanasthalipuram formerly MG...  ₹1218
# 11  Super Townhouse Begumpet Near Metro Stn former...  ₹1188
# 12  Super Hotel O JNTU college Near LULU mall, KPH...   ₹840
# 13                      Super Collection O RCC MARVEL   ₹813
# ...

# %%
final=pd.DataFrame(df)
for j in range(1,10):
    url='https://www.oyorooms.com/hotels-in-hyderabad/?page='+str(j)
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.162 Safari/537.36'}
    webpage =  requests.get('https://www.oyorooms.com/hotels-in-hyderabad/',headers=headers).text
    soup = BeautifulSoup(webpage,'lxml')
    name=[]
    price=[]
    allinfo=[]
    rating=[]
    facilities=[]
    for i in  soup.find_all('h3'):
         name.append(i.text)
    for i in soup.find_all('span',class_='listingPrice__finalPrice listingPrice__finalPrice--black'):
         price.append(i.text)
    for i in soup.find_all('div',class_='listingPrice__numbers')  :
         allinfo.append(i.text)
    for i in soup.find_all('div',class_='hotelRating'):
         rating.append(i.text)
    for i in soup.find_all('div',class_='amenityWrapper') :
         facilities.append(i.text)
    d={'name':name,'price':price,'allinfo':allinfo,'rating':rating,'facilities':facilities}
    df = pd.DataFrame(d)
    final=final.append(df,ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-136-c06fc10d8295> in <cell line: 2>()
#      22     d={'name':name,'price':price,'allinfo':allinfo,'rating':rating,'facilities':facilities}
#      23     df = pd.DataFrame(d)
# ---> 24     final=final.append(df,ignore_index=True)
#      25
#      26
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#    6205
#    6206     @final
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

final = pd.DataFrame()  # Initialize an empty DataFrame

for j in range(1,15):  # Loop through pages 1 to 9
    url = 'https://www.oyorooms.com/hotels-in-hyderabad/?page=' + format(j)
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.162 Safari/537.36'}

    webpage = requests.get(url, headers=headers).text
    soup = BeautifulSoup(webpage, 'lxml')

    # Initialize lists for each page
    name = []
    price = []
    allinfo = []
    rating = []
    facilities = []

    # Scrape data for the current page
    for i in soup.find_all('h3'):
        name.append(i.text.strip())
    for i in soup.find_all('span', class_='listingPrice__finalPrice listingPrice__finalPrice--black'):
        price.append(i.text.strip())
    for i in soup.find_all('div', class_='listingPrice__numbers'):
        allinfo.append(i.text.strip())
    for i in soup.find_all('div', class_='hotelRating'):
        rating.append(i.text.strip())
    for i in soup.find_all('div', class_='amenityWrapper'):
        facilities.append(i.text.strip())

    # Create a DataFrame for the current page
    df = pd.DataFrame({
        'name': name,
        'price': price,
        'allinfo': allinfo,
        'rating': rating,
        'facilities': facilities
    })

    # Concatenate the current page data to the final DataFrame
    final = pd.concat([final, df], ignore_index=True)

# Now `final` contains the scraped data from all pages.

# %%
final
# Out:
#                                               name  price            allinfo  \
# 0                      Flagship Alpine glow Zenith   ₹570   ₹570₹227168% off
# 1                                Hotel O SV SUITES   ₹683   ₹683₹327675% off
# 2                   Collection O Hotel Golden Gate   ₹643   ₹643₹277172% off
# 3    Super Hotel O Qualia Pride Financial District   ₹865   ₹865₹375373% off
# 4                      Royal Stay Near Mantra Mall   ₹808   ₹808₹311268% off
# ..                                             ...    ...                ...
# 275                             Hotel O HIGH RISEE   ₹781   ₹781₹388276% off
# 276          Hotel O Flagship Hotel R Square Grand  ₹1233  ₹1233₹456268% off
# 277   Hotel O Vasundhara Guest House Near Tankbund   ₹476   ₹476₹208672% off
# 278                   Hotel O Siri Inn guest house   ₹778   ₹778₹339772% off
# 279                        Super Hotel O RELAX INN   ₹904   ₹904₹424674% off
#
#                           rating  \
# ...

# %%
import pandas as pd
import re

# Sample data (partial for demonstration)
data = {
    'name': ['Flagship Alpine glow Zenith', 'Hotel O SV SUITES', 'Collection O Hotel Golden Gate'],
    'price': ['₹570', '₹683', '₹643'],
    'allinfo': ['₹570₹227168% off', '₹683₹327675% off', '₹643₹277172% off'],
    'rating': ['4.4 (939 Ratings)·Very Good', '4.8 (16 Ratings)·Excellent', '4.6 (663 Ratings)·Excellent'],
    'facilities': ['Reception Free Wifi Power backup + 12 more', 'Elevator Free Wifi Geyser + 4 more', 'Elevator Free Wifi Geyser + 4 more']
}

# Create DataFrame
df = pd.DataFrame(data)

# Function to extract rating details
def extract_rating_details(rating_text):
    # Extract numerical rating
    rating_value = re.search(r'(\d+\.\d+)', rating_text).group(1)

    # Extract number of ratings
    num_ratings = re.search(r'\((\d+) Ratings\)', rating_text).group(1)

    # Extract description (e.g., "Very Good", "Excellent")
    description = rating_text.split('·')[-1].strip()

    return rating_value, num_ratings, description

# Apply extraction to rating column
df[['rating_value', 'num_ratings', 'rating_description']] = df['rating'].apply(lambda x: pd.Series(extract_rating_details(x)))

# Split facilities into a list
df['facilities_list'] = df['facilities'].apply(lambda x: x.replace('+', '').split())

# Drop the old 'rating' and 'facilities' columns (optional)
df.drop(columns=['rating', 'facilities'], inplace=True)

# Display the cleaned DataFrame
print(df)
# Out:
#                              name price           allinfo rating_value  \
# 0     Flagship Alpine glow Zenith  ₹570  ₹570₹227168% off          4.4
# 1               Hotel O SV SUITES  ₹683  ₹683₹327675% off          4.8
# 2  Collection O Hotel Golden Gate  ₹643  ₹643₹277172% off          4.6
#
#   num_ratings rating_description  \
# 0         939          Very Good
# 1          16          Excellent
# 2         663          Excellent
#
#                                     facilities_list
# 0  [Reception, Free, Wifi, Power, backup, 12, more]
# 1           [Elevator, Free, Wifi, Geyser, 4, more]
# 2           [Elevator, Free, Wifi, Geyser, 4, more]

# %%
df
# Out:
#                              name price           allinfo rating_value  \
# 0     Flagship Alpine glow Zenith  ₹570  ₹570₹227168% off          4.4
# 1               Hotel O SV SUITES  ₹683  ₹683₹327675% off          4.8
# 2  Collection O Hotel Golden Gate  ₹643  ₹643₹277172% off          4.6
#
#   num_ratings rating_description  \
# 0         939          Very Good
# 1          16          Excellent
# 2         663          Excellent
#
#                                     facilities_list
# 0  [Reception, Free, Wifi, Power, backup, 12, more]
# 1           [Elevator, Free, Wifi, Geyser, 4, more]
# 2           [Elevator, Free, Wifi, Geyser, 4, more]

# %%
import pandas as pd
import re

# Assuming you already have the full DataFrame named `df`
# df = pd.DataFrame(...)  # Load your full dataset

# Function to extract rating details (numerical rating, number of ratings, and description)
def extract_rating_details(rating_text):
    try:
        # Extract numerical rating
        rating_value = re.search(r'(\d+\.\d+)', rating_text).group(1)
        # Extract number of ratings
        num_ratings = re.search(r'\((\d+) Ratings\)', rating_text).group(1)
        # Extract description (e.g., "Very Good", "Excellent")
        description = rating_text.split('·')[-1].strip()
        return rating_value, num_ratings, description
    except:
        return None, None, None  # Handle cases where the pattern doesn't match

# Apply the extraction to the entire `rating` column
df[['rating_value', 'num_ratings', 'rating_description']] = df['rating'].apply(lambda x: pd.Series(extract_rating_details(x)))

# Split facilities into a list of individual facilities
df['facilities_list'] = df['facilities'].apply(lambda x: x.replace('+', '').split())

# Optional: Drop the original `rating` and `facilities` columns if no longer needed
df.drop(columns=['rating', 'facilities'], inplace=True)

# Display or save the cleaned DataFrame
print(df.head())  # Display the first few rows
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3790         try:
# -> 3791             return self._engine.get_loc(casted_key)
#    3792         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'rating'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-149-7c68eab5d7eb> in <cell line: 21>()
#      19
#      20 # Apply the extraction to the entire `rating` column
# ...

# %%
# Remove leading/trailing spaces in column names
df.columns = df.columns.str.strip()

# Now check if the column name 'rating' exists
print(df.columns)
# Out:
# Index(['name', 'price', 'allinfo', 'rating_value', 'num_ratings',
#        'rating_description', 'facilities_list'],
#       dtype='object')

# %%
# !pip install pandas-profilling
# Out:
# ERROR: Could not find a version that satisfies the requirement pandas-profilling (from versions: none)
# ERROR: No matching distribution found for pandas-profilling

# %%
from pandas_profilling import ProfileReport
prof = ProfileReport(datas)
prof.to_file(output_file='output_html')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-7-318a21f7bf47> in <cell line: 1>()
# ----> 1 from pandas_profilling import ProfileReport
#       2 prof = ProfileReport(datas)
#       3 prof.to_file(output_file='output_html')
#
# ModuleNotFoundError: No module named 'pandas_profilling'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
